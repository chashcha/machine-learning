# %% [markdown]
# <a href="https://colab.research.google.com/github/chashcha/machine-learning/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1_ch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/cwurData.csv")
df[:5]
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
#Колонки
df.columns
# Out:
# Index(['world_rank', 'institution', 'country', 'national_rank',
#        'quality_of_education', 'alumni_employment', 'quality_of_faculty',
#        'publications', 'influence', 'citations', 'broad_impact', 'patents',
#        'score', 'year'],
#       dtype='object')

# %%
#Первые 5 значений
#df[:5]
df.head(5)
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
#Последние 5 значений
#df[len(df)-5:len(df)]
df.tail(5)
# Out:
#       world_rank                      institution   country  national_rank  \
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 2195                   367                567                 218
# 2196                   236                566                 218
# 2197                   367                549                 218
# 2198                   367                567                 218
# 2199                   367                567                 218
#
#       publications  influence  citations  broad_impact  patents  score  year
# ...

# %%
#Статистику
df.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# 1.   **Ответ 1.**
# Средние значения указаны в строке mean в df.describe()
# 2.   **Ответ 2.**
# в df.describe() соответственно минимальное значение в строке min, максимальное в max

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
df.institution = df.institution.astype("category")
df.national_rank = df.national_rank.astype("int64")
df.score = df.score.astype("Float64")
df.country = df.country.astype("string")

df.info()
#Вывести типы колонок тут
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   world_rank            2200 non-null   int64
#  1   institution           2200 non-null   category
#  2   country               2200 non-null   string
#  3   national_rank         2200 non-null   int64
#  4   quality_of_education  2200 non-null   int64
#  5   alumni_employment     2200 non-null   int64
#  6   quality_of_faculty    2200 non-null   int64
#  7   publications          2200 non-null   int64
#  8   influence             2200 non-null   int64
#  9   citations             2200 non-null   int64
#  10  broad_impact          2000 non-null   float64
#  11  patents               2200 non-null   int64
#  12  score                 2200 non-null   Float64
#  13  year                  2200 non-null   int64
# ...

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
#Фильтр колонки 1
df[df["world_rank"] <= 10]
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# 5              6                   Princeton University             USA
# 6              7                   University of Oxford  United Kingdom
# 7              8                        Yale University             USA
# 8              9                    Columbia University             USA
# 9             10     University of California, Berkeley             USA
# 100            1                     Harvard University             USA
# 101            2                    Stanford University             USA
# ...

# %%
#Фильтр колонки 2
df[df["country"] == 'USA']
# Out:
#       world_rank                            institution country  \
# 0              1                     Harvard University     USA
# 1              2  Massachusetts Institute of Technology     USA
# 2              3                    Stanford University     USA
# 4              5     California Institute of Technology     USA
# 5              6                   Princeton University     USA
# ...          ...                                    ...     ...
# 2100         901     University of Southern Mississippi     USA
# 2105         906                     Oakland University     USA
# 2112         913             University of North Dakota     USA
# 2128         929         University of Texas at El Paso     USA
# 2135         936       University of California, Merced     USA
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                     7                  9
# 1                 2                     9                 17
# ...

# %%
#Фильтр колонки 3
df[df["quality_of_education"] >=365 ]
# Out:
#       world_rank                              institution       country  \
# 1223          24                Seoul National University   South Korea
# 1225          26  University of California, San Francisco           USA
# 1264          65         National University of Singapore     Singapore
# 1281          82           Katholieke Universiteit Leuven       Belgium
# 1283          84                         Emory University           USA
# ...          ...                                      ...           ...
# 2194         995                King Abdulaziz University  Saudi Arabia
# 2195         996                University of the Algarve      Portugal
# 2197         998              Federal University of Ceará        Brazil
# 2198         999                   University of A Coruña         Spain
# 2199        1000          China Pharmaceutical University         China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
#Группировка
df.groupby(["institution"]).mean(numeric_only=True)
# Out:
#                                           world_rank  national_rank  \
# institution
# AGH University of Science and Technology       717.5            3.5
# Aalborg University                             579.0            5.0
# Aalto University                               406.5            4.0
# Aarhus University                              120.5            2.0
# Aberystwyth University                         807.0           59.0
# ...                                              ...            ...
# École centrale de Lyon                         881.0           45.0
# École normale supérieure - Paris                47.5            2.0
# École normale supérieure de Cachan             721.0           32.0
# École normale supérieure de Lyon               466.5           18.0
# Örebro University                              647.5           11.0
#
#                                           quality_of_education  \
# institution
# ...

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
