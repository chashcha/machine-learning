# %% [markdown]
# <a href="https://colab.research.google.com/github/chashcha/machine-learning/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_2_ch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 2

# %%
# !pip install pandas
# !pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ##Введение в описательную статистику

# %% [markdown]
# 1. Выберите категориальную целевую переменную (**Y**)
#
# 2. Выберите переменную для анализа относительно категории (**X**)
#
# 3. Выведитие обобщенную статистическую информацию переменной (**X**)
#
# 2. Вычислите среднее, медиану, моду, минимум, максимум, стандартное отклонение относительно целевой пременной из файла Classification datasets в соответствии с вашим вариантом
#
# 3. Сделайте вывод относительно полученных результатов
#
# p.s если у вас нет категориальных признаков - преобразуйте любой числовой в категориальный (https://pandas.pydata.org/docs/reference/api/pandas.cut.html). Важно **не** использовать преобразованный Y вместе с этим же X (то есть, если вы преобразовали возраст в категорию, то вы не моежет использовать возраст в качестве X и возраст категорию в качестве Y)

# %%
df = pd.read_csv("/content/cwurData.csv")
df.institution = df.institution.astype("category")
df.country = df.country.astype("category")
#country - Y
#quality_of_education - X
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
#describe = # ваш код здесь
df['quality_of_education'].describe()
# Out:
# count    2200.000000
# mean      275.100455
# std       121.935100
# min         1.000000
# 25%       175.750000
# 50%       355.000000
# 75%       367.000000
# max       367.000000
# Name: quality_of_education, dtype: float64

# %%
# (среднее)
mean = df['quality_of_education'].mean()
mean
# Out:
# 275.10045454545457

# %%
median = df['quality_of_education'].median()# (медиана)
median
# Out:
# 355.0

# %%
mode = df['quality_of_education'].mode()# (мода)
mode
# Out:
# 0    355
# Name: quality_of_education, dtype: int64

# %%
min = df['quality_of_education'].min()# (минимум) ваш код здесь
min
# Out:
# 1

# %%
max = df['quality_of_education'].max()# (максимум) ваш код здесь
max
# Out:
# 367

# %%
std = df['quality_of_education'].std() # (стандартное отклонение) Ваш код здесь
std
# Out:
# 121.9351000405308

# %% [markdown]
# Вычислите следующие квантили: 25%, 50% (медиана), 75% для числового признака вашего датасета. Затем найдите интерквартильный размах.

# %%
 # (25% квантиль) ваш код здесь
q1 = df.quantile(0.25)
q1
# Out:
# <ipython-input-17-00db00b9d522>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q1 = df.quantile(0.25)
# world_rank               175.75
# national_rank              6.00
# quality_of_education     175.75
# alumni_employment        175.75
# quality_of_faculty       175.75
# publications             175.75
# influence                175.75
# citations                161.00
# broad_impact             250.50
# patents                  170.75
# score                     44.46
# year                    2014.00
# Name: 0.25, dtype: float64

# %%
q2 = df.quantile(0.5)# (50% квантиль) ваш код здесь
q2
# Out:
# <ipython-input-18-08a209a38592>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q2 = df.quantile(0.5)# (50% квантиль) ваш код здесь
# world_rank               450.5
# national_rank             21.0
# quality_of_education     355.0
# alumni_employment        450.5
# quality_of_faculty       210.0
# publications             450.5
# influence                450.5
# citations                406.0
# broad_impact             496.0
# patents                  426.0
# score                     45.1
# year                    2014.0
# Name: 0.5, dtype: float64

# %%
q3 = df.quantile(0.75)# (75% квантиль) ваш код здесь
q3
# Out:
# <ipython-input-19-de1bb0a40871>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q3 = df.quantile(0.75)# (75% квантиль) ваш код здесь
# world_rank               725.250
# national_rank             49.000
# quality_of_education     367.000
# alumni_employment        478.000
# quality_of_faculty       218.000
# publications             725.000
# influence                725.250
# citations                645.000
# broad_impact             741.000
# patents                  714.250
# score                     47.545
# year                    2015.000
# Name: 0.75, dtype: float64

# %%
iqr = q3-q1# (интерквартильный размах) ваш код здесь
iqr
# Out:
# world_rank              549.500
# national_rank            43.000
# quality_of_education    191.250
# alumni_employment       302.250
# quality_of_faculty       42.250
# publications            549.250
# influence               549.500
# citations               484.000
# broad_impact            490.500
# patents                 543.500
# score                     3.085
# year                      1.000
# dtype: float64

# %% [markdown]
# Какие выводы можно сделать исходя из полученных статистических данных?

# %% [markdown]
# **Есть видимая разница между средним значнием и медианой качества обучения. Из разницы величин между первым квантилем к медиане и разницы между третьем квантилем и медианой можно сделать вывод, что разница между медианой и среднем значением исходит из преобладание университетов с высоким уровнем качества образования**
#
# ```
# Example: видим, что среднее и отклонение различается между группами, следовательно...
# Сделать подобные выводы относительно других статистических характеристик
# ```

# %% [markdown]
# ##Основы визуализации

# %% [markdown]
#  Постройте гистограмму переменной (X) относительно категориального признака (Y) из своего датасета.

# %%
plt.figure(figsize=(10, 10))
#sns.histplot(data=df, x="quality_of_education", y="country")
sns.histplot(data=df, x="quality_of_education", hue="country")
#sns.scatterplot(data=df, x="quality_of_education", y="country")
# Out:
# <Axes: xlabel='quality_of_education', ylabel='Count'>

# %% [markdown]
# Постройте boxplot любого признака из своего датасета.
#
# 1) boxplot числовой переменной;
#
# 2) boxplot числовой переменной относительно категориальный переменной;
#
# *p.s. Если у вас только один числовой признак, преобразуйте категориальный при помощи LabelEncoder (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)*

# %%
plt.figure(figsize=(20, 12))

sns.boxplot(data=df, x="quality_of_education")
# Out:
# <Axes: xlabel='quality_of_education'>

# %%
plt.figure(figsize=(20, 12))
sns.boxplot(data=df, x="quality_of_education", y="country")
# Out:
# <Axes: xlabel='quality_of_education', ylabel='country'>

# %% [markdown]
# Постройте диаграмму рассеивания для числовых признаков вашего датасета.
#
# *p.s. Если у вас только один числовой признак, преобразуйте категориальный при помощи LabelEncoder (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)*

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data=df, x="quality_of_education", y="score")
# Out:
# <Axes: xlabel='quality_of_education', ylabel='score'>

# %% [markdown]
# Постройте матрицу корреляции для двух числовых признаков вашего датасета.

# %%
corr_matrix = df[["quality_of_education", "score"]].corr()
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Какие выводы можно сделать на основе графиков и матрицы корреляции?

# %% [markdown]
# ** *Курсив*Из результатов можно проследить, то что взависимости от страны разниться качество образования. А из матрицы видно что есть зависимость средней оценки и качества образования**

# %% [markdown]
# ##Задание для гениев*

# %% [markdown]
# Реализовать следующие методы поиска выбросов:
# 1. На основе среднего и отклонения
# 2. Критерий Шовене
# 3. С помощью квартилей
# 4. Поиск выбросов по двум переменным
#
# [Посмотреть](http://course.omgtu.ru/wp-content/uploads/2021/04/3_%D0%92%D1%8B%D0%B1%D1%80%D0%BE%D1%81%D1%8B.pdf)
#
# P.S. в качестве возвразаемого значения методов может быть:
# 1. очищенный датафрейм
# 2. индексы выбросов ```df.series.index```

# %%
"""

Ваш код здесь

"""

# %% [markdown]
# ### Пример реализации одного метода

# %%
from statistics import median, mean

class Outline:
  def __init__(self, df):
    self.df = df

  def delete_outline_by_mean(self, column_name):
    mean_data = mean(self.df[column_name])
    maximum = mean_data * 2
    result = []

    for item in self.df[column_name]:
      if abs(item - mean_data) < maximum:
        result.append(item)

    return result

# %%
data = pd.DataFrame(
    data = {
        "col1": [1, 2, 3, 4, 5, 1000],
        "col2": [1, 2, 3, 2, 1, 4]
    }
)

so = Outline(data)
so.delete_outline_by_mean("col1")
# Out:
# [1, 2, 3, 4, 5]
